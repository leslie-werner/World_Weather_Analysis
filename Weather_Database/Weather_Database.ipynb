# %%
#import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Create random lats and lngs combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 780

# %%
#import the requests library
import requests

#import the Api key
from config import weather_api_key

# %%
#starting URL for weather map api call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" +weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93583efc23004b87c68c00c4aab6bab5'

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | castro
# Processing Record 4 of Set 1 | linxia
# Processing Record 5 of Set 1 | butaritari
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | mahebourg
# Processing Record 9 of Set 1 | pitimbu
# Processing Record 10 of Set 1 | norden
# Processing Record 11 of Set 1 | san policarpo
# Processing Record 12 of Set 1 | vestmannaeyjar
# Processing Record 13 of Set 1 | balkanabat
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | viedma
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | tuggurt
# City not found. Skipping...
# Processing Record 18 of Set 1 | praia da vitoria
# Processing Record 19 of Set 1 | qaanaaq
# Processing Record 20 of Set 1 | muhos
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | siniscola
# Processing Record 23 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 1 | svetlogorsk
# Processing Record 25 of Set 1 | kapaa
# Processing Record 26 of Set 1 | san cristobal
# Processing Record 27 of Set 1 | naze
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 1 | upernavik
# Processing Record 31 of Set 1 | panzhihua
# Processing Record 32 of Set 1 | touros
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | victoria
# Processing Record 36 of Set 1 | yumen
# Processing Record 37 of Set 1 | seoul
# Processing Record 38 of Set 1 | marzuq
# Processing Record 39 of Set 1 | shelburne
# Processing Record 40 of Set 1 | kruisfontein
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | cabo san lucas
# Processing Record 43 of Set 1 | ornskoldsvik
# Processing Record 44 of Set 1 | kyra
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | saskylakh
# Processing Record 47 of Set 1 | lata
# Processing Record 48 of Set 1 | chuy
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | caxambu
# Processing Record 1 of Set 2 | port alfred
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | kutum
# Processing Record 4 of Set 2 | new norfolk
# Processing Record 5 of Set 2 | tuatapere
# Processing Record 6 of Set 2 | nikolskoye
# Processing Record 7 of Set 2 | puerto ayora
# Processing Record 8 of Set 2 | aguadilla
# Processing Record 9 of Set 2 | yanam
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | de aar
# Processing Record 12 of Set 2 | namibe
# Processing Record 13 of Set 2 | midland
# Processing Record 14 of Set 2 | general roca
# Processing Record 15 of Set 2 | mataura
# Processing Record 16 of Set 2 | hasaki
# Processing Record 17 of Set 2 | waingapu
# Processing Record 18 of Set 2 | hobart
# Processing Record 19 of Set 2 | capaci
# Processing Record 20 of Set 2 | kerman
# Processing Record 21 of Set 2 | bodden town
# Processing Record 22 of Set 2 | dikson
# Processing Record 23 of Set 2 | atar
# Processing Record 24 of Set 2 | crato
# Processing Record 25 of Set 2 | jamestown
# Processing Record 26 of Set 2 | east london
# Processing Record 27 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 28 of Set 2 | masterton
# Processing Record 29 of Set 2 | enid
# Processing Record 30 of Set 2 | arteaga
# Processing Record 31 of Set 2 | scottsburgh
# City not found. Skipping...
# Processing Record 32 of Set 2 | vao
# Processing Record 33 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 2 | cayenne
# Processing Record 35 of Set 2 | saldanha
# Processing Record 36 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 2 | mannargudi
# Processing Record 38 of Set 2 | sisimiut
# Processing Record 39 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 2 | chapeco
# Processing Record 41 of Set 2 | ribeira grande
# Processing Record 42 of Set 2 | carnarvon
# Processing Record 43 of Set 2 | mackay
# Processing Record 44 of Set 2 | monrovia
# Processing Record 45 of Set 2 | staryy nadym
# Processing Record 46 of Set 2 | aleysk
# Processing Record 47 of Set 2 | hualmay
# Processing Record 48 of Set 2 | youkounkoun
# Processing Record 49 of Set 2 | souillac
# Processing Record 50 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 3 | mazamari
# Processing Record 3 of Set 3 | karasjok
# Processing Record 4 of Set 3 | biaora
# Processing Record 5 of Set 3 | sitka
# Processing Record 6 of Set 3 | wiarton
# Processing Record 7 of Set 3 | takoradi
# Processing Record 8 of Set 3 | padang
# Processing Record 9 of Set 3 | havoysund
# Processing Record 10 of Set 3 | lingao
# Processing Record 11 of Set 3 | grindavik
# Processing Record 12 of Set 3 | bandar-e lengeh
# Processing Record 13 of Set 3 | pasighat
# Processing Record 14 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 3 | cherskiy
# Processing Record 16 of Set 3 | hilo
# Processing Record 17 of Set 3 | makamba
# Processing Record 18 of Set 3 | thompson
# Processing Record 19 of Set 3 | visby
# Processing Record 20 of Set 3 | havelock
# Processing Record 21 of Set 3 | tuktoyaktuk
# Processing Record 22 of Set 3 | tasiilaq
# Processing Record 23 of Set 3 | pedernales
# Processing Record 24 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 3 | leningradskiy
# Processing Record 26 of Set 3 | saint-philippe
# Processing Record 27 of Set 3 | fairbanks
# Processing Record 28 of Set 3 | uttiramerur
# Processing Record 29 of Set 3 | los llanos de aridane
# Processing Record 30 of Set 3 | zhanakorgan
# Processing Record 31 of Set 3 | conceicao do araguaia
# Processing Record 32 of Set 3 | nemuro
# Processing Record 33 of Set 3 | pevek
# Processing Record 34 of Set 3 | arkhangelsk
# Processing Record 35 of Set 3 | steenwijk
# Processing Record 36 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 3 | mount gambier
# Processing Record 38 of Set 3 | yerbogachen
# Processing Record 39 of Set 3 | palora
# Processing Record 40 of Set 3 | lebu
# Processing Record 41 of Set 3 | fort nelson
# Processing Record 42 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 3 | ponta do sol
# Processing Record 44 of Set 3 | kagadi
# Processing Record 45 of Set 3 | cariati
# Processing Record 46 of Set 3 | pisco
# Processing Record 47 of Set 3 | bow island
# Processing Record 48 of Set 3 | pacific grove
# Processing Record 49 of Set 3 | ketchikan
# Processing Record 50 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 4 | sharya
# Processing Record 2 of Set 4 | sawtell
# Processing Record 3 of Set 4 | marawi
# Processing Record 4 of Set 4 | chokurdakh
# Processing Record 5 of Set 4 | arraial do cabo
# Processing Record 6 of Set 4 | torbay
# Processing Record 7 of Set 4 | alofi
# Processing Record 8 of Set 4 | oro valley
# Processing Record 9 of Set 4 | codrington
# Processing Record 10 of Set 4 | maues
# Processing Record 11 of Set 4 | portland
# Processing Record 12 of Set 4 | tabialan
# City not found. Skipping...
# Processing Record 13 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 4 | smithers
# Processing Record 15 of Set 4 | coquimbo
# Processing Record 16 of Set 4 | puno
# Processing Record 17 of Set 4 | siyabuswa
# Processing Record 18 of Set 4 | vardo
# Processing Record 19 of Set 4 | garowe
# Processing Record 20 of Set 4 | airai
# Processing Record 21 of Set 4 | san juan de arama
# Processing Record 22 of Set 4 | port-gentil
# Processing Record 23 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 4 | cidreira
# Processing Record 25 of Set 4 | saint-pierre
# Processing Record 26 of Set 4 | unity
# Processing Record 27 of Set 4 | hamadan
# Processing Record 28 of Set 4 | ranfurly
# Processing Record 29 of Set 4 | kommunar
# Processing Record 30 of Set 4 | avera
# Processing Record 31 of Set 4 | constitucion
# Processing Record 32 of Set 4 | sao filipe
# Processing Record 33 of Set 4 | camacha
# Processing Record 34 of Set 4 | muli
# Processing Record 35 of Set 4 | killybegs
# Processing Record 36 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 37 of Set 4 | georgetown
# Processing Record 38 of Set 4 | hami
# Processing Record 39 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 40 of Set 4 | grimshaw
# Processing Record 41 of Set 4 | tahe
# Processing Record 42 of Set 4 | tabas
# Processing Record 43 of Set 4 | floresta
# Processing Record 44 of Set 4 | leua
# Processing Record 45 of Set 4 | ambon
# Processing Record 46 of Set 4 | houston
# Processing Record 47 of Set 4 | gornopravdinsk
# Processing Record 48 of Set 4 | cam pha
# City not found. Skipping...
# Processing Record 49 of Set 4 | sembe
# Processing Record 50 of Set 4 | tahta
# Processing Record 1 of Set 5 | sabha
# Processing Record 2 of Set 5 | kavaratti
# Processing Record 3 of Set 5 | ancud
# Processing Record 4 of Set 5 | kochubey
# Processing Record 5 of Set 5 | nioro
# Processing Record 6 of Set 5 | barcelos
# Processing Record 7 of Set 5 | bredasdorp
# Processing Record 8 of Set 5 | bambous virieux
# Processing Record 9 of Set 5 | amarkantak
# Processing Record 10 of Set 5 | mildura
# Processing Record 11 of Set 5 | wawa
# Processing Record 12 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 5 | ambilobe
# Processing Record 14 of Set 5 | kodiak
# Processing Record 15 of Set 5 | mar del plata
# Processing Record 16 of Set 5 | komsomolskiy
# Processing Record 17 of Set 5 | ponta delgada
# Processing Record 18 of Set 5 | saint george
# Processing Record 19 of Set 5 | albion
# Processing Record 20 of Set 5 | christchurch
# Processing Record 21 of Set 5 | jaguariuna
# Processing Record 22 of Set 5 | karratha
# Processing Record 23 of Set 5 | katsuura
# Processing Record 24 of Set 5 | goderich
# Processing Record 25 of Set 5 | beeville
# Processing Record 26 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 5 | santa isabel
# Processing Record 28 of Set 5 | tucurui
# Processing Record 29 of Set 5 | lavrentiya
# Processing Record 30 of Set 5 | medea
# Processing Record 31 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 5 | hambantota
# Processing Record 33 of Set 5 | pochutla
# Processing Record 34 of Set 5 | foz
# Processing Record 35 of Set 5 | san patricio
# Processing Record 36 of Set 5 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 37 of Set 5 | burlington
# Processing Record 38 of Set 5 | qesarya
# Processing Record 39 of Set 5 | sabang
# Processing Record 40 of Set 5 | andenes
# Processing Record 41 of Set 5 | necochea
# Processing Record 42 of Set 5 | lashio
# Processing Record 43 of Set 5 | augusto correa
# Processing Record 44 of Set 5 | tual
# Processing Record 45 of Set 5 | khatanga
# Processing Record 46 of Set 5 | lotung
# City not found. Skipping...
# Processing Record 47 of Set 5 | kemijarvi
# Processing Record 48 of Set 5 | fort myers beach
# Processing Record 49 of Set 5 | panguna
# Processing Record 50 of Set 5 | rio gallegos
# Processing Record 1 of Set 6 | faanui
# Processing Record 2 of Set 6 | carazinho
# Processing Record 3 of Set 6 | kununurra
# Processing Record 4 of Set 6 | villa sandino
# Processing Record 5 of Set 6 | al
# City not found. Skipping...
# Processing Record 6 of Set 6 | hudson bay
# Processing Record 7 of Set 6 | norman wells
# Processing Record 8 of Set 6 | geraldton
# Processing Record 9 of Set 6 | stromness
# Processing Record 10 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 6 | alvaraes
# Processing Record 12 of Set 6 | uige
# Processing Record 13 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 14 of Set 6 | niksar
# Processing Record 15 of Set 6 | angoche
# Processing Record 16 of Set 6 | jalu
# Processing Record 17 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 18 of Set 6 | lar
# Processing Record 19 of Set 6 | saint-francois
# Processing Record 20 of Set 6 | verkhoyansk
# Processing Record 21 of Set 6 | baley
# Processing Record 22 of Set 6 | belle fourche
# Processing Record 23 of Set 6 | baltasi
# Processing Record 24 of Set 6 | tautira
# Processing Record 25 of Set 6 | longyearbyen
# Processing Record 26 of Set 6 | zhezkazgan
# Processing Record 27 of Set 6 | maniitsoq
# Processing Record 28 of Set 6 | odweyne
# Processing Record 29 of Set 6 | qasigiannguit
# Processing Record 30 of Set 6 | dicabisagan
# Processing Record 31 of Set 6 | nanortalik
# Processing Record 32 of Set 6 | brandfort
# Processing Record 33 of Set 6 | iqaluit
# Processing Record 34 of Set 6 | suksun
# Processing Record 35 of Set 6 | port blair
# Processing Record 36 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 37 of Set 6 | sao joao da barra
# Processing Record 38 of Set 6 | severo-kurilsk
# Processing Record 39 of Set 6 | jiangyou
# Processing Record 40 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 41 of Set 6 | san felipe
# Processing Record 42 of Set 6 | vila do maio
# Processing Record 43 of Set 6 | tugulym
# Processing Record 44 of Set 6 | saint-joseph
# Processing Record 45 of Set 6 | saint anthony
# Processing Record 46 of Set 6 | broken hill
# Processing Record 47 of Set 6 | nagapattinam
# Processing Record 48 of Set 6 | wum
# Processing Record 49 of Set 6 | fuerte olimpo
# Processing Record 50 of Set 6 | axixa do tocantins
# City not found. Skipping...
# Processing Record 1 of Set 7 | wanning
# Processing Record 2 of Set 7 | shingu
# Processing Record 3 of Set 7 | hovd
# Processing Record 4 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 6 of Set 7 | nome
# Processing Record 7 of Set 7 | mpophomeni
# Processing Record 8 of Set 7 | bathsheba
# Processing Record 9 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 7 | fortuna
# Processing Record 11 of Set 7 | bonga
# Processing Record 12 of Set 7 | praxedis guerrero
# Processing Record 13 of Set 7 | mattru
# Processing Record 14 of Set 7 | thai binh
# Processing Record 15 of Set 7 | mayo
# Processing Record 16 of Set 7 | vila franca do campo
# Processing Record 17 of Set 7 | port keats
# Processing Record 18 of Set 7 | hit
# Processing Record 19 of Set 7 | santa cruz
# Processing Record 20 of Set 7 | chudovo
# Processing Record 21 of Set 7 | kaitangata
# Processing Record 22 of Set 7 | rawson
# Processing Record 23 of Set 7 | chilliwack
# Processing Record 24 of Set 7 | avallon
# Processing Record 25 of Set 7 | larsnes
# Processing Record 26 of Set 7 | henties bay
# Processing Record 27 of Set 7 | west lafayette
# Processing Record 28 of Set 7 | kieta
# Processing Record 29 of Set 7 | berlevag
# Processing Record 30 of Set 7 | sandwick
# Processing Record 31 of Set 7 | adrar
# Processing Record 32 of Set 7 | sao gabriel da cachoeira
# Processing Record 33 of Set 7 | gasa
# Processing Record 34 of Set 7 | hithadhoo
# Processing Record 35 of Set 7 | yinchuan
# Processing Record 36 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 37 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 7 | didsbury
# Processing Record 39 of Set 7 | khomeynishahr
# City not found. Skipping...
# Processing Record 40 of Set 7 | abiy adi
# City not found. Skipping...
# Processing Record 41 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 42 of Set 7 | jacareacanga
# Processing Record 43 of Set 7 | meulaboh
# Processing Record 44 of Set 7 | callaway
# Processing Record 45 of Set 7 | safaga
# Processing Record 46 of Set 7 | quatre cocos
# Processing Record 47 of Set 7 | mandalgovi
# Processing Record 48 of Set 7 | vertientes
# Processing Record 49 of Set 7 | klaksvik
# Processing Record 50 of Set 7 | kirensk
# Processing Record 1 of Set 8 | abu samrah
# Processing Record 2 of Set 8 | manado
# Processing Record 3 of Set 8 | san jose
# Processing Record 4 of Set 8 | aquiraz
# Processing Record 5 of Set 8 | provideniya
# Processing Record 6 of Set 8 | gaoual
# Processing Record 7 of Set 8 | kletskaya
# Processing Record 8 of Set 8 | srednekolymsk
# Processing Record 9 of Set 8 | ghanzi
# Processing Record 10 of Set 8 | rocha
# Processing Record 11 of Set 8 | grand gaube
# Processing Record 12 of Set 8 | shimoda
# Processing Record 13 of Set 8 | port lincoln
# Processing Record 14 of Set 8 | oranjemund
# Processing Record 15 of Set 8 | ouahigouya
# Processing Record 16 of Set 8 | la ronge
# Processing Record 17 of Set 8 | puro
# Processing Record 18 of Set 8 | talnakh
# Processing Record 19 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 8 | esperance
# Processing Record 21 of Set 8 | andilamena
# Processing Record 22 of Set 8 | russell
# Processing Record 23 of Set 8 | aksarka
# Processing Record 24 of Set 8 | fomboni
# Processing Record 25 of Set 8 | ramtek
# Processing Record 26 of Set 8 | palana
# Processing Record 27 of Set 8 | krasnoselkup
# Processing Record 28 of Set 8 | bafq
# Processing Record 29 of Set 8 | kolno
# Processing Record 30 of Set 8 | taltal
# Processing Record 31 of Set 8 | hondo
# Processing Record 32 of Set 8 | tiznit
# Processing Record 33 of Set 8 | bilma
# Processing Record 34 of Set 8 | ahipara
# Processing Record 35 of Set 8 | smiltene
# Processing Record 36 of Set 8 | fallon
# Processing Record 37 of Set 8 | walla walla
# Processing Record 38 of Set 8 | bani
# Processing Record 39 of Set 8 | dingle
# Processing Record 40 of Set 8 | malanville
# Processing Record 41 of Set 8 | teahupoo
# Processing Record 42 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 43 of Set 8 | bima
# Processing Record 44 of Set 8 | qui nhon
# Processing Record 45 of Set 8 | domodossola
# Processing Record 46 of Set 8 | mago
# Processing Record 47 of Set 8 | tiksi
# Processing Record 48 of Set 8 | kasongo-lunda
# Processing Record 49 of Set 8 | sioux lookout
# Processing Record 50 of Set 8 | puerto ayacucho
# Processing Record 1 of Set 9 | jackson
# Processing Record 2 of Set 9 | pangnirtung
# Processing Record 3 of Set 9 | yoichi
# Processing Record 4 of Set 9 | las palmas
# Processing Record 5 of Set 9 | lawrenceburg
# Processing Record 6 of Set 9 | ljubinje
# Processing Record 7 of Set 9 | mayumba
# Processing Record 8 of Set 9 | udachnyy
# Processing Record 9 of Set 9 | cambrils
# Processing Record 10 of Set 9 | olafsvik
# Processing Record 11 of Set 9 | locri
# Processing Record 12 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 9 | nuevo progreso
# Processing Record 14 of Set 9 | zachagansk
# City not found. Skipping...
# Processing Record 15 of Set 9 | crab hill
# City not found. Skipping...
# Processing Record 16 of Set 9 | pali
# Processing Record 17 of Set 9 | sept-iles
# Processing Record 18 of Set 9 | ukiah
# Processing Record 19 of Set 9 | lae
# Processing Record 20 of Set 9 | alamos
# Processing Record 21 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 9 | rock sound
# Processing Record 23 of Set 9 | ayagoz
# Processing Record 24 of Set 9 | witu
# Processing Record 25 of Set 9 | storm lake
# Processing Record 26 of Set 9 | samarai
# Processing Record 27 of Set 9 | weligama
# Processing Record 28 of Set 9 | okha
# Processing Record 29 of Set 9 | kigoma
# Processing Record 30 of Set 9 | nelson bay
# Processing Record 31 of Set 9 | sergeyevka
# Processing Record 32 of Set 9 | umm kaddadah
# Processing Record 33 of Set 9 | lompoc
# Processing Record 34 of Set 9 | jiayuguan
# Processing Record 35 of Set 9 | sintereag
# Processing Record 36 of Set 9 | kerema
# Processing Record 37 of Set 9 | turukhansk
# Processing Record 38 of Set 9 | itaituba
# Processing Record 39 of Set 9 | kangaatsiaq
# Processing Record 40 of Set 9 | yar-sale
# Processing Record 41 of Set 9 | byron bay
# Processing Record 42 of Set 9 | ulaangom
# Processing Record 43 of Set 9 | sorland
# Processing Record 44 of Set 9 | baykit
# Processing Record 45 of Set 9 | belmonte
# Processing Record 46 of Set 9 | ust-kulom
# Processing Record 47 of Set 9 | bulgan
# Processing Record 48 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 49 of Set 9 | kaeo
# Processing Record 50 of Set 9 | macas
# Processing Record 1 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 2 of Set 10 | anadyr
# Processing Record 3 of Set 10 | vuktyl
# Processing Record 4 of Set 10 | vysokogornyy
# Processing Record 5 of Set 10 | vestmanna
# Processing Record 6 of Set 10 | snasa
# Processing Record 7 of Set 10 | dharchula
# Processing Record 8 of Set 10 | willich
# Processing Record 9 of Set 10 | shenjiamen
# Processing Record 10 of Set 10 | isangel
# Processing Record 11 of Set 10 | omutinskoye
# City not found. Skipping...
# Processing Record 12 of Set 10 | rasht
# Processing Record 13 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 10 | yarada
# Processing Record 15 of Set 10 | ndjole
# Processing Record 16 of Set 10 | bad aussee
# Processing Record 17 of Set 10 | te anau
# Processing Record 18 of Set 10 | naantali
# Processing Record 19 of Set 10 | sungaipenuh
# Processing Record 20 of Set 10 | aloja
# Processing Record 21 of Set 10 | sindand
# City not found. Skipping...
# Processing Record 22 of Set 10 | tiarei
# Processing Record 23 of Set 10 | manzhouli
# Processing Record 24 of Set 10 | berbera
# Processing Record 25 of Set 10 | pervomayskoye
# Processing Record 26 of Set 10 | makakilo city
# Processing Record 27 of Set 10 | flinders
# Processing Record 28 of Set 10 | tafresh
# Processing Record 29 of Set 10 | labuan
# Processing Record 30 of Set 10 | edd
# Processing Record 31 of Set 10 | akureyri
# Processing Record 32 of Set 10 | alyangula
# Processing Record 33 of Set 10 | jaisalmer
# Processing Record 34 of Set 10 | lodwar
# Processing Record 35 of Set 10 | coahuayana
# Processing Record 36 of Set 10 | jumla
# Processing Record 37 of Set 10 | ibimirim
# Processing Record 38 of Set 10 | tabora
# Processing Record 39 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 40 of Set 10 | kota kinabalu
# Processing Record 41 of Set 10 | emmett
# Processing Record 42 of Set 10 | skjervoy
# Processing Record 43 of Set 10 | urrao
# Processing Record 44 of Set 10 | kabompo
# Processing Record 45 of Set 10 | mamallapuram
# Processing Record 46 of Set 10 | moussoro
# Processing Record 47 of Set 10 | ostrovnoy
# Processing Record 48 of Set 10 | akyab
# Processing Record 49 of Set 10 | angul
# Processing Record 50 of Set 10 | tubuala
# Processing Record 1 of Set 11 | ozinki
# Processing Record 2 of Set 11 | mabaruma
# Processing Record 3 of Set 11 | najran
# Processing Record 4 of Set 11 | ugoofaaru
# Processing Record 5 of Set 11 | palmer
# Processing Record 6 of Set 11 | slantsy
# Processing Record 7 of Set 11 | belousovka
# Processing Record 8 of Set 11 | namatanai
# Processing Record 9 of Set 11 | ca mau
# Processing Record 10 of Set 11 | vila velha
# Processing Record 11 of Set 11 | soubre
# Processing Record 12 of Set 11 | vila
# Processing Record 13 of Set 11 | lorengau
# Processing Record 14 of Set 11 | gat
# Processing Record 15 of Set 11 | tura
# Processing Record 16 of Set 11 | quelimane
# Processing Record 17 of Set 11 | port hardy
# Processing Record 18 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 19 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 11 | flin flon
# Processing Record 21 of Set 11 | kijang
# Processing Record 22 of Set 11 | tadine
# Processing Record 23 of Set 11 | alto piquiri
# Processing Record 24 of Set 11 | victor harbor
# Processing Record 25 of Set 11 | kurilsk
# Processing Record 26 of Set 11 | alta floresta
# Processing Record 27 of Set 11 | laguna
# Processing Record 28 of Set 11 | ganzhou
# Processing Record 29 of Set 11 | high level
# Processing Record 30 of Set 11 | tonneins
# Processing Record 31 of Set 11 | grand-santi
# Processing Record 32 of Set 11 | hailar
# Processing Record 33 of Set 11 | ngozi
# Processing Record 34 of Set 11 | mandera
# Processing Record 35 of Set 11 | swindon
# Processing Record 36 of Set 11 | ilulissat
# Processing Record 37 of Set 11 | shakawe
# Processing Record 38 of Set 11 | shasta lake
# Processing Record 39 of Set 11 | yuzhno-kurilsk
# Processing Record 40 of Set 11 | aplahoue
# Processing Record 41 of Set 11 | maputo
# Processing Record 42 of Set 11 | nadvoitsy
# Processing Record 43 of Set 11 | poum
# Processing Record 44 of Set 11 | jacqueville
# Processing Record 45 of Set 11 | rehoboth
# Processing Record 46 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 47 of Set 11 | kahului
# Processing Record 48 of Set 11 | narsaq
# Processing Record 49 of Set 11 | haines junction
# Processing Record 50 of Set 11 | yulara
# Processing Record 1 of Set 12 | guerrero negro
# Processing Record 2 of Set 12 | mount isa
# Processing Record 3 of Set 12 | labuhan
# Processing Record 4 of Set 12 | baculin
# Processing Record 5 of Set 12 | bengkulu
# Processing Record 6 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 12 | minna
# Processing Record 8 of Set 12 | rumoi
# Processing Record 9 of Set 12 | kabanjahe
# Processing Record 10 of Set 12 | alibunan
# Processing Record 11 of Set 12 | tvoroyri
# Processing Record 12 of Set 12 | vostok
# Processing Record 13 of Set 12 | hargeysa
# Processing Record 14 of Set 12 | vanimo
# Processing Record 15 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 16 of Set 12 | qingdao
# Processing Record 17 of Set 12 | mopipi
# Processing Record 18 of Set 12 | angoram
# Processing Record 19 of Set 12 | sebastian
# Processing Record 20 of Set 12 | luxeuil-les-bains
# Processing Record 21 of Set 12 | fortuna foothills
# Processing Record 22 of Set 12 | estelle
# Processing Record 23 of Set 12 | bardejov
# Processing Record 24 of Set 12 | nouadhibou
# Processing Record 25 of Set 12 | amazar
# Processing Record 26 of Set 12 | novosheshminsk
# Processing Record 27 of Set 12 | lianzhou
# Processing Record 28 of Set 12 | dakar
# Processing Record 29 of Set 12 | shagonar
# Processing Record 30 of Set 12 | seguin
# Processing Record 31 of Set 12 | hrubieszow
# Processing Record 32 of Set 12 | colares
# Processing Record 33 of Set 12 | acajutla
# Processing Record 34 of Set 12 | kysyl-syr
# Processing Record 35 of Set 12 | ambulu
# Processing Record 36 of Set 12 | lovozero
# Processing Record 37 of Set 12 | yatou
# Processing Record 38 of Set 12 | suwannaphum
# Processing Record 39 of Set 12 | kanina
# Processing Record 40 of Set 12 | casalmaggiore
# Processing Record 41 of Set 12 | broome
# Processing Record 42 of Set 12 | walvis bay
# Processing Record 43 of Set 12 | novikovo
# Processing Record 44 of Set 12 | clyde river
# Processing Record 45 of Set 12 | acapulco
# Processing Record 46 of Set 12 | bilibino
# Processing Record 47 of Set 12 | yeppoon
# Processing Record 48 of Set 12 | alugan
# Processing Record 49 of Set 12 | traverse city
# Processing Record 50 of Set 12 | katherine
# Processing Record 1 of Set 13 | hinjilikatu
# Processing Record 2 of Set 13 | deputatskiy
# Processing Record 3 of Set 13 | altay
# Processing Record 4 of Set 13 | chapais
# Processing Record 5 of Set 13 | urambo
# Processing Record 6 of Set 13 | tessalit
# Processing Record 7 of Set 13 | ewa beach
# Processing Record 8 of Set 13 | meridian
# Processing Record 9 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 10 of Set 13 | tver
# Processing Record 11 of Set 13 | burica
# City not found. Skipping...
# Processing Record 12 of Set 13 | yelan-kolenovskiy
# Processing Record 13 of Set 13 | luganville
# Processing Record 14 of Set 13 | zarichne
# Processing Record 15 of Set 13 | lazaro cardenas
# Processing Record 16 of Set 13 | marshall
# Processing Record 17 of Set 13 | roald
# Processing Record 18 of Set 13 | plyussa
# Processing Record 19 of Set 13 | panaba
# Processing Record 20 of Set 13 | topchikha
# Processing Record 21 of Set 13 | martapura
# Processing Record 22 of Set 13 | tieli
# Processing Record 23 of Set 13 | lander
# Processing Record 24 of Set 13 | sicamous
# Processing Record 25 of Set 13 | toul
# Processing Record 26 of Set 13 | anloga
# Processing Record 27 of Set 13 | malanje
# Processing Record 28 of Set 13 | barguzin
# Processing Record 29 of Set 13 | teknaf
# Processing Record 30 of Set 13 | tilichiki
# Processing Record 31 of Set 13 | pabrade
# Processing Record 32 of Set 13 | sibu
# Processing Record 33 of Set 13 | capreol
# Processing Record 34 of Set 13 | tlahualilo
# City not found. Skipping...
# Processing Record 35 of Set 13 | sunbury
# Processing Record 36 of Set 13 | semey
# Processing Record 37 of Set 13 | pingliang
# Processing Record 38 of Set 13 | vyartsilya
# Processing Record 39 of Set 13 | fernie
# Processing Record 40 of Set 13 | nuuk
# Processing Record 41 of Set 13 | puerto colombia
# Processing Record 42 of Set 13 | chumikan
# Processing Record 43 of Set 13 | ucluelet
# Processing Record 44 of Set 13 | bulata
# Processing Record 45 of Set 13 | bahia blanca
# Processing Record 46 of Set 13 | waddan
# Processing Record 47 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 48 of Set 13 | carutapera
# Processing Record 49 of Set 13 | bischwiller
# Processing Record 50 of Set 13 | coihaique
# Processing Record 1 of Set 14 | grafton
# Processing Record 2 of Set 14 | caceres
# Processing Record 3 of Set 14 | berkakit
# Processing Record 4 of Set 14 | redondo
# Processing Record 5 of Set 14 | bembereke
# Processing Record 6 of Set 14 | uyemskiy
# Processing Record 7 of Set 14 | evensk
# Processing Record 8 of Set 14 | nefteyugansk
# Processing Record 9 of Set 14 | tres passos
# Processing Record 10 of Set 14 | damietta
# Processing Record 11 of Set 14 | kingman
# Processing Record 12 of Set 14 | akalkot
# Processing Record 13 of Set 14 | san ramon
# Processing Record 14 of Set 14 | yangambi
# Processing Record 15 of Set 14 | bundaberg
# Processing Record 16 of Set 14 | escanaba
# Processing Record 17 of Set 14 | sorong
# Processing Record 18 of Set 14 | narok
# Processing Record 19 of Set 14 | opunake
# Processing Record 20 of Set 14 | lakatoro
# Processing Record 21 of Set 14 | tambura
# Processing Record 22 of Set 14 | slave lake
# Processing Record 23 of Set 14 | aljezur
# Processing Record 24 of Set 14 | lincoln
# Processing Record 25 of Set 14 | chor
# Processing Record 26 of Set 14 | kiama
# Processing Record 27 of Set 14 | hamilton
# Processing Record 28 of Set 14 | cap malheureux
# Processing Record 29 of Set 14 | urengoy
# Processing Record 30 of Set 14 | la asuncion
# Processing Record 31 of Set 14 | high rock
# Processing Record 32 of Set 14 | rosarito
# Processing Record 33 of Set 14 | lasa
# Processing Record 34 of Set 14 | bac lieu
# Processing Record 35 of Set 14 | store heddinge
# Processing Record 36 of Set 14 | ormara
# Processing Record 37 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 38 of Set 14 | port macquarie
# Processing Record 39 of Set 14 | acarau
# Processing Record 40 of Set 14 | porto novo
# Processing Record 41 of Set 14 | burnie
# Processing Record 42 of Set 14 | muros
# Processing Record 43 of Set 14 | batagay-alyta
# Processing Record 44 of Set 14 | puri
# Processing Record 45 of Set 14 | markova
# Processing Record 46 of Set 14 | thiruvananthapuram
# Processing Record 47 of Set 14 | jieshi
# Processing Record 48 of Set 14 | daru
# Processing Record 49 of Set 14 | strezhevoy
# Processing Record 50 of Set 14 | cairns
# Processing Record 1 of Set 15 | bajo baudo
# City not found. Skipping...
# Processing Record 2 of Set 15 | chicama
# Processing Record 3 of Set 15 | prince rupert
# Processing Record 4 of Set 15 | moose factory
# Processing Record 5 of Set 15 | khovu-aksy
# Processing Record 6 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 7 of Set 15 | nantucket
# Processing Record 8 of Set 15 | hostotipaquillo
# Processing Record 9 of Set 15 | arys
# Processing Record 10 of Set 15 | maloshuyka
# City not found. Skipping...
# Processing Record 11 of Set 15 | dalbandin
# Processing Record 12 of Set 15 | vieste
# Processing Record 13 of Set 15 | podgornoye
# Processing Record 14 of Set 15 | lagoa
# Processing Record 15 of Set 15 | villa del rosario
# Processing Record 16 of Set 15 | tigil
# Processing Record 17 of Set 15 | bonavista
# Processing Record 18 of Set 15 | verkhoturye
# Processing Record 19 of Set 15 | khani
# Processing Record 20 of Set 15 | deniliquin
# Processing Record 21 of Set 15 | barra do garcas
# Processing Record 22 of Set 15 | butte
# Processing Record 23 of Set 15 | artigas
# Processing Record 24 of Set 15 | kloulklubed
# Processing Record 25 of Set 15 | shintomi
# Processing Record 26 of Set 15 | taoudenni
# Processing Record 27 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 28 of Set 15 | stornoway
# Processing Record 29 of Set 15 | carroll
# Processing Record 30 of Set 15 | belaya gora
# Processing Record 31 of Set 15 | muisne
# Processing Record 32 of Set 15 | aklavik
# Processing Record 33 of Set 15 | hastings
# Processing Record 34 of Set 15 | muroran
# Processing Record 35 of Set 15 | beringovskiy
# Processing Record 36 of Set 15 | port hedland
# Processing Record 37 of Set 15 | lososina
# Processing Record 38 of Set 15 | erenhot
# Processing Record 39 of Set 15 | nhulunbuy
# Processing Record 40 of Set 15 | ziyamet
# City not found. Skipping...
# Processing Record 41 of Set 15 | saquena
# Processing Record 42 of Set 15 | micheweni
# Processing Record 43 of Set 15 | kizukuri
# Processing Record 44 of Set 15 | amapa
# Processing Record 45 of Set 15 | auki
# Processing Record 46 of Set 15 | hobyo
# Processing Record 47 of Set 15 | poli
# Processing Record 48 of Set 15 | uaua
# Processing Record 49 of Set 15 | isiro
# Processing Record 50 of Set 15 | jamame
# Processing Record 1 of Set 16 | eydhafushi
# Processing Record 2 of Set 16 | amarpur
# Processing Record 3 of Set 16 | port augusta
# Processing Record 4 of Set 16 | severomuysk
# Processing Record 5 of Set 16 | susangerd
# Processing Record 6 of Set 16 | le port
# Processing Record 7 of Set 16 | palu
# Processing Record 8 of Set 16 | beira
# Processing Record 9 of Set 16 | athabasca
# Processing Record 10 of Set 16 | buala
# Processing Record 11 of Set 16 | keshan
# City not found. Skipping...
# Processing Record 12 of Set 16 | canyon lake
# Processing Record 13 of Set 16 | mtimbira
# Processing Record 14 of Set 16 | santona
# Processing Record 15 of Set 16 | viesca
# Processing Record 16 of Set 16 | miandoab
# Processing Record 17 of Set 16 | antalaha
# Processing Record 18 of Set 16 | durango
# Processing Record 19 of Set 16 | abbeville
# Processing Record 20 of Set 16 | mecca
# Processing Record 21 of Set 16 | karpathos
# Processing Record 22 of Set 16 | toamasina
# Processing Record 23 of Set 16 | halalo
# City not found. Skipping...
# Processing Record 24 of Set 16 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 25 of Set 16 | altea
# Processing Record 26 of Set 16 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 16 | eureka
# Processing Record 28 of Set 16 | eyl
# Processing Record 29 of Set 16 | mrirt
# City not found. Skipping...
# Processing Record 30 of Set 16 | jacksonville
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather = requests.get(url).json()
city_weather

# %%
len(city_data)
# Out:
# 708

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Atuona  -9.8000 -139.0333     77.23        80          29
# 1       Cape Town -33.9258   18.4232     69.12        74           0
# 2          Castro -24.7911  -50.0119     60.46        98         100
# 3          Linxia  35.6003  103.2064      8.04        84          23
# 4      Butaritari   3.0707  172.7902     81.70        77          25
# 5          Albany  42.6001  -73.9662     14.81        64         100
# 6  Port Elizabeth -33.9180   25.5701     69.10        77          75
# 7       Mahebourg -20.4081   57.7000     80.89        78          40
# 8         Pitimbu  -7.4706  -34.8086     82.99        74          83
# 9          Norden  53.6000    7.2000     46.96        71           9
#
#    Wind Speed Country Current Description
# 0       14.54      PF          light rain
# 1        8.01      ZA           clear sky
# 2        5.75      BR     overcast clouds
# 3        2.62      CN          few clouds
# 4       19.64      KI          light rain
# 5       10.00      US     overcast clouds
# 6       11.50      ZA       broken clouds
# 7        8.05      MU    scattered clouds
# 8        7.07      BR          light rain
# 9       36.53      DE           clear sky

# %%
new_city_data = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
new_city_data_df = city_data_df[new_city_data]
new_city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Atuona      PF  -9.8000 -139.0333     77.23        80          29
# 1   Cape Town      ZA -33.9258   18.4232     69.12        74           0
# 2      Castro      BR -24.7911  -50.0119     60.46        98         100
# 3      Linxia      CN  35.6003  103.2064      8.04        84          23
# 4  Butaritari      KI   3.0707  172.7902     81.70        77          25
#
#    Wind Speed Current Description
# 0       14.54          light rain
# 1        8.01           clear sky
# 2        5.75     overcast clouds
# 3        2.62          few clouds
# 4       19.64          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
